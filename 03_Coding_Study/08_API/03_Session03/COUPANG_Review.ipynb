# %%
import requests

# %%
params = {
    "productId": "2453926",
    "page": "2",
    "size": "10",
    "sortBy": "ORDER_SCORE_ASC",
    "ratingSummary": "true",
    "ratings": "",
    "market": ""
}

headers = {
    "accept": "application/json, text/plain, */*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "priority": "u=1, i",
    "referer": "https://www.coupang.com/vp/products/2453926?itemId=20343930073&vendorItemId=3000014814&pickType=COU_PICK&q=%EB%94%B8%EA%B8%B0%EC%9E%BC&searchId=94eae9b96010722&sourceType=search&itemsCount=36&searchRank=1&rank=1&traceId=mmu19rzo",
    "sec-ch-ua": "\"Not:A-Brand\";v=\"99\", \"Google Chrome\";v=\"145\", \"Chromium\";v=\"145\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36",
    "Cookie" : "x-coupang-target-market=KR; x-coupang-accept-language=ko-KR; PCID=17676781561581897791932; MARKETID=17676781561581897791932; trac_src=1139000; trac_spec=10799999; trac_addtag=400; trac_ctag=6900027377; trac_lptag=AF7490655; trac_itime=20260215023053; bm_ss=ab8e18ef4e; ak_bmsc=1825A2C64D0162EEB9DB25EF1CA7C371~000000000000000000000000000000~; bm_so=052FE4D1E226444823BDD66AC9A5AEE3BC929D3E6073BDC6A56DA6416F63E958~...; sid=ad15d0fdb77a4c16898c44d30ffa0169f3a09873; bm_mi=20C816E3A0A9CA8C6F1B6156B93837DC~~1; bm_lso=052FE4D1E226444823BDD66AC9A5AEE3BC929D3E6073BDC6A56DA6416F63E958~...~1773716933195; _abck=A3C46F756E4C45B8E308CCB3E53ECC56~0~...~-1~-1~1773720532~AAQAAAAF%2f%2f%2f%2f%2fxCrCkMpC0+1z1TVsfTlFdEPIi0qhcaf9MiMuWHrlJeFPU0T61V2OXpYBP6ACPjU7YfXPx8nkeQI0oWWHmHtg3GLLa4Q%2fRxbbdCb~-1; bm_sz=134063A201A9647041CE07CA805EA603~...~3617606~3682370; bm_s=...; bm_sv=957573FBF3002226441875FF32455E14~~1"
}

serviece_url = 'https://www.coupang.com/next-api/review'

response = requests.get(serviece_url, params=params, headers=headers)

print(response.status_code)
# Out:
# 403

# %%
# TLS 핑거프린트 우회 라이브러리
from curl_cffi import requests
import pandas as pd
from pprint import pprint

# %% [markdown]
# product id : "2453926"

# %%
# 리뷰 데이터 수집
def get_coupang_reviews(product_id, page, size=10):

    headers = {
        "accept": "application/json, text/plain, */*",
        "accept-encoding": "gzip, deflate, br, zstd",
        "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "priority": "u=1, i",
        "referer": "https://www.coupang.com/vp/products/2453926?itemId=20343930073&vendorItemId=3000014814&pickType=COU_PICK&q=%EB%94%B8%EA%B8%B0%EC%9E%BC&searchId=94eae9b96010722&sourceType=search&itemsCount=36&searchRank=1&rank=1&traceId=mmu19rzo",
        "sec-ch-ua": "\"Not:A-Brand\";v=\"99\", \"Google Chrome\";v=\"145\", \"Chromium\";v=\"145\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36",
        "Cookie" : "x-coupang-target-market=KR; x-coupang-accept-language=ko-KR; PCID=17676781561581897791932; MARKETID=17676781561581897791932; trac_src=1139000; trac_spec=10799999; trac_addtag=400; trac_ctag=6900027377; trac_lptag=AF7490655; trac_itime=20260215023053; bm_ss=ab8e18ef4e; ak_bmsc=1825A2C64D0162EEB9DB25EF1CA7C371~000000000000000000000000000000~; bm_so=052FE4D1E226444823BDD66AC9A5AEE3BC929D3E6073BDC6A56DA6416F63E958~...; sid=ad15d0fdb77a4c16898c44d30ffa0169f3a09873; bm_mi=20C816E3A0A9CA8C6F1B6156B93837DC~~1; bm_lso=052FE4D1E226444823BDD66AC9A5AEE3BC929D3E6073BDC6A56DA6416F63E958~...~1773716933195; _abck=A3C46F756E4C45B8E308CCB3E53ECC56~0~...~-1~-1~1773720532~AAQAAAAF%2f%2f%2f%2f%2fxCrCkMpC0+1z1TVsfTlFdEPIi0qhcaf9MiMuWHrlJeFPU0T61V2OXpYBP6ACPjU7YfXPx8nkeQI0oWWHmHtg3GLLa4Q%2fRxbbdCb~-1; bm_sz=134063A201A9647041CE07CA805EA603~...~3617606~3682370; bm_s=...; bm_sv=957573FBF3002226441875FF32455E14~~1"
    }

    # 1) 세션 생성 : 브라우저가 요청하듯 흉내(페이지 전환), 쿠키 자동관리

    session = requests.Session(impersonate='chrome') # 크롬 브라우저 처럼 TLS 흉내를 낸다!
    session.headers.update(headers)

    # 2) 메인 페이지 방문 : 쿠키 자동으로 수령!

    session.get('https://www.coupang.com/')

    # 3) 리뷰 API 호출 데이터 수집

    serviece_url = 'https://www.coupang.com/next-api/review'

    params = {
        "productId": product_id,
        "page": page,
        "size": size,
        "sortBy": "ORDER_SCORE_ASC",
        "ratingSummary": "true",
        "ratings": "",
        "market": ""
    }

    response = session.get(serviece_url, params=params)

    results = []

    if response.status_code == 200:
        try:
            result = response.json()
            # pprint(result)
            reviews = result['rData']['paging']['contents']
            for review in reviews:
                try:
                    results.append({
                        'content': review['content'],
                        'displayName': review['displayName'],
                        'helpfulCount': review['helpfulCount'],
                        'helpfulFalseCount': review['helpfulFalseCount'],
                        'helpfulTrueCount': review['helpfulTrueCount'],
                        'productId': review['productId'],
                        'itemId': review['itemId'],
                        'itemName': review['itemName'],
                        'rating': review['rating'],
                        'createdAt': review['createdAt']
                    })
                except:
                    continue
            return results
        except:
            pass

get_coupang_reviews("2453926", 1)
# Out:
# [{'content': '딸기잼은 진짜 복음자리만 삽니다. 이건 진심이에요. 한 번 먹어보고 나서 다른 잼은 손이 안 가더라고요. 그냥 입에 착 붙는 맛이랄까요, 너무 달지도 않고 딸기 향이 인위적이지 않아서 질리지가 않아요. 국산 딸기랑 설탕만 써서 홈메이드 방식으로 만들었다고 하는데, 먹어보면 진짜 그 말이 이해가 돼요. 마트에서 파는 다른 잼들이랑은 결이 달라요. 딸기 씨도 살아있고, 질감도 너무 매끄럽지 않아서 먹는 재미가 있거든요.\n우리 집 애들이 잼을 좋아하는 편인데, 이거는 진짜 잘 먹어요. 빵에 발라주면 순식간에 없어지는데, 그게 다 이 잼 덕분인 것 같아요. 아이들이 음식에 까다로운 편이라 아무 잼이나 사면 안 먹을 때도 있는데, 복음자리 딸기잼은 단 한 번도 실패한 적이 없어요. 한 번 맛 들이고 나서는 다른 잼은 쳐다도 안 봐요. 그게 좀 무섭기도 하지만(웃음) 잘 먹어주니 다행이죠.\n어제 저녁에 주문했는데 오늘 아침에 이미 도착해있었어요. 새벽배송 진짜 대단하더라고요. 아침에 일어나서 빵 꺼내놓고 잼 발라줬는데, 어제 주문한 게 오늘 아침 식탁에 오른다는 게 아직도 신기해요. 아이들 아침 챙겨주면서 이런 것들이 얼마나 편한지 새삼 느꼈어요. 바쁜 아침에 딱 필요한 타이밍에 와줘서 너무 고마웠어요.\n380g짜리라 금방 없어지겠다 싶었는데, 생각보다 양이 꽤 되더라고요. 빵에 넉넉하게 발라도 한 통이 제법 가요. 유리병이라 보관도 깔끔하고, 냉장고에 두고 쓸 때마다 꺼내기도 편해요. 뚜껑도 딱 맞게 닫히고, 내용물이 잘 보여서 남은 양 확인하기도 좋아요.\n딸기잼 고민하고 계신 분들 있으면 그냥 이거 사세요. 후회 없어요. 저는 앞으로도 딸기잼은 복음자리만 살 것 같아요. 이미 여러 통째 사봤는데, 매번 만족하고 또 주문하게 되는 그런 제품이에요. 주변에도 추천 많이 했고, 다들 사고 나서 잘 샀다고 하더라고요. 믿고 사는 잼, 복음자리 딸기잼이에요.\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200
# ...

# %%
# 리뷰 정보 수집
def get_coupang_reviews_info(product_id, page, size=10):

    headers = {
        "accept": "application/json, text/plain, */*",
        "accept-encoding": "gzip, deflate, br, zstd",
        "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "priority": "u=1, i",
        "referer": "https://www.coupang.com/vp/products/2453926?itemId=20343930073&vendorItemId=3000014814&pickType=COU_PICK&q=%EB%94%B8%EA%B8%B0%EC%9E%BC&searchId=94eae9b96010722&sourceType=search&itemsCount=36&searchRank=1&rank=1&traceId=mmu19rzo",
        "sec-ch-ua": "\"Not:A-Brand\";v=\"99\", \"Google Chrome\";v=\"145\", \"Chromium\";v=\"145\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36",
        "Cookie" : "x-coupang-target-market=KR; x-coupang-accept-language=ko-KR; PCID=17676781561581897791932; MARKETID=17676781561581897791932; trac_src=1139000; trac_spec=10799999; trac_addtag=400; trac_ctag=6900027377; trac_lptag=AF7490655; trac_itime=20260215023053; bm_ss=ab8e18ef4e; ak_bmsc=1825A2C64D0162EEB9DB25EF1CA7C371~000000000000000000000000000000~; bm_so=052FE4D1E226444823BDD66AC9A5AEE3BC929D3E6073BDC6A56DA6416F63E958~...; sid=ad15d0fdb77a4c16898c44d30ffa0169f3a09873; bm_mi=20C816E3A0A9CA8C6F1B6156B93837DC~~1; bm_lso=052FE4D1E226444823BDD66AC9A5AEE3BC929D3E6073BDC6A56DA6416F63E958~...~1773716933195; _abck=A3C46F756E4C45B8E308CCB3E53ECC56~0~...~-1~-1~1773720532~AAQAAAAF%2f%2f%2f%2f%2fxCrCkMpC0+1z1TVsfTlFdEPIi0qhcaf9MiMuWHrlJeFPU0T61V2OXpYBP6ACPjU7YfXPx8nkeQI0oWWHmHtg3GLLa4Q%2fRxbbdCb~-1; bm_sz=134063A201A9647041CE07CA805EA603~...~3617606~3682370; bm_s=...; bm_sv=957573FBF3002226441875FF32455E14~~1"
    }

    # 1) 세션 생성 : 브라우저가 요청하듯 흉내(페이지 전환), 쿠키 자동관리

    session = requests.Session(impersonate='chrome') # 크롬 브라우저 처럼 TLS 흉내를 낸다!
    session.headers.update(headers)

    # 2) 메인 페이지 방문 : 쿠키 자동으로 수령!

    session.get('https://www.coupang.com/')

    # 3) 리뷰 API 호출 데이터 수집

    serviece_url = 'https://www.coupang.com/next-api/review'

    params = {
        "productId": product_id,
        "page": page,
        "size": size,
        "sortBy": "ORDER_SCORE_ASC",
        "ratingSummary": "true",
        "ratings": "",
        "market": ""
    }

    response = session.get(serviece_url, params=params)

    if response.status_code == 200:
        result = response.json()
        ratingSummaryTotal_info = result['rData']['ratingSummaryTotal']
        totalPage = result['rData']['paging']['totalPage']
        return totalPage, ratingSummaryTotal_info

total_page, rating_summary = get_coupang_reviews_info("2453926", 1)

# %%
results = []
for page in range(1, 10): # total_page+1
    result = get_coupang_reviews("2453926", 1)
    results.extend(result)

pprint(len(results))
pprint(results)

product_id = "2453926"

df = pd.DataFrame(results)
df.head()
df.to_json(f'./쿠팡 리뷰 수집{product_id}.json', orient='records', force_ascii=False, indent=2)
# Out:
# 90
# [{'content': '딸기잼은 진짜 복음자리만 삽니다. 이건 진심이에요. 한 번 먹어보고 나서 다른 잼은 손이 안 가더라고요. 그냥 입에 '
#              '착 붙는 맛이랄까요, 너무 달지도 않고 딸기 향이 인위적이지 않아서 질리지가 않아요. 국산 딸기랑 설탕만 써서 '
#              '홈메이드 방식으로 만들었다고 하는데, 먹어보면 진짜 그 말이 이해가 돼요. 마트에서 파는 다른 잼들이랑은 결이 '
#              '달라요. 딸기 씨도 살아있고, 질감도 너무 매끄럽지 않아서 먹는 재미가 있거든요.\n'
#              '우리 집 애들이 잼을 좋아하는 편인데, 이거는 진짜 잘 먹어요. 빵에 발라주면 순식간에 없어지는데, 그게 다 이 잼 '
#              '덕분인 것 같아요. 아이들이 음식에 까다로운 편이라 아무 잼이나 사면 안 먹을 때도 있는데, 복음자리 딸기잼은 단 '
#              '한 번도 실패한 적이 없어요. 한 번 맛 들이고 나서는 다른 잼은 쳐다도 안 봐요. 그게 좀 무섭기도 하지만(웃음) '
#              '잘 먹어주니 다행이죠.\n'
#              '어제 저녁에 주문했는데 오늘 아침에 이미 도착해있었어요. 새벽배송 진짜 대단하더라고요. 아침에 일어나서 빵 꺼내놓고 '
#              '잼 발라줬는데, 어제 주문한 게 오늘 아침 식탁에 오른다는 게 아직도 신기해요. 아이들 아침 챙겨주면서 이런 것들이 '
#              '얼마나 편한지 새삼 느꼈어요. 바쁜 아침에 딱 필요한 타이밍에 와줘서 너무 고마웠어요.\n'
#              '380g짜리라 금방 없어지겠다 싶었는데, 생각보다 양이 꽤 되더라고요. 빵에 넉넉하게 발라도 한 통이 제법 가요. '
#              '유리병이라 보관도 깔끔하고, 냉장고에 두고 쓸 때마다 꺼내기도 편해요. 뚜껑도 딱 맞게 닫히고, 내용물이 잘 보여서 '
# ...
