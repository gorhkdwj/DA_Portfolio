# %% [markdown]
# ### 네이버 증권 삼성전자 일별 시세 추출

# %% [markdown]
# https://finance.naver.com/item/sise_day.naver?code=005930&page=1

# %%
import requests
import pandas as pd

service_url = 'https://finance.naver.com/item/sise_day.naver'

code = '005930'

params = {
    'code' : code
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

for i in range(1,11):
    params['page'] = i
    response = requests.get(service_url, params=params, headers=headers)

    if response.status_code == 200:
        print(f"--- {i}페이지 HTML 정보 출력 ---")
        print(response.text)
        print("-" * 50)
# Out:
# --- 1페이지 HTML 정보 출력 ---
#
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <title>Npay 증권</title>
#
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/common.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/finance_header.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/layout.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/main.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock2.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock3.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/world.css">
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
# 				<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 				<td align="center"><span class="tah p10 gray03">2026.03.17</span></td>
# 				<td class="num"><span class="tah p11">196,300</span></td>
# 				<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				7,600
# 				</span>
# 			</td>
# 				<td class="num"><span class="tah p11">198,000</span></td>
# 				<td class="num"><span class="tah p11">198,000</span></td>
# 				<td class="num"><span class="tah p11">195,500</span></td>
# 				<td class="num"><span class="tah p11">8,275,912</span></td>
# 				</tr>
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.16</span></td>
# 					<td class="num"><span class="tah p11">188,700</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				5,200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">184,600</span></td>
# 					<td class="num"><span class="tah p11">189,000</span></td>
# 					<td class="num"><span class="tah p11">183,600</span></td>
# 					<td class="num"><span class="tah p11">19,747,901</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.13</span></td>
# 					<td class="num"><span class="tah p11">183,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				4,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">180,000</span></td>
# 					<td class="num"><span class="tah p11">186,200</span></td>
# 					<td class="num"><span class="tah p11">179,900</span></td>
# 					<td class="num"><span class="tah p11">19,566,331</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.12</span></td>
# 					<td class="num"><span class="tah p11">187,900</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				2,100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">186,600</span></td>
# 					<td class="num"><span class="tah p11">190,000</span></td>
# 					<td class="num"><span class="tah p11">185,900</span></td>
# 					<td class="num"><span class="tah p11">20,440,753</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.11</span></td>
# 					<td class="num"><span class="tah p11">190,000</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">193,000</span></td>
# 					<td class="num"><span class="tah p11">194,800</span></td>
# 					<td class="num"><span class="tah p11">187,700</span></td>
# 					<td class="num"><span class="tah p11">24,311,356</span></td>
# 					</tr>
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="1" bgcolor="#e1e1e1"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.10</span></td>
# 					<td class="num"><span class="tah p11">187,900</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				14,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">187,600</span></td>
# 					<td class="num"><span class="tah p11">191,500</span></td>
# 					<td class="num"><span class="tah p11">184,300</span></td>
# 					<td class="num"><span class="tah p11">33,530,170</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.09</span></td>
# 					<td class="num"><span class="tah p11">173,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				14,700
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">173,500</span></td>
# 					<td class="num"><span class="tah p11">175,500</span></td>
# 					<td class="num"><span class="tah p11">167,300</span></td>
# 					<td class="num"><span class="tah p11">43,066,020</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.06</span></td>
# 					<td class="num"><span class="tah p11">188,200</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				3,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">186,100</span></td>
# 					<td class="num"><span class="tah p11">189,700</span></td>
# 					<td class="num"><span class="tah p11">181,000</span></td>
# 					<td class="num"><span class="tah p11">29,522,650</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.05</span></td>
# 					<td class="num"><span class="tah p11">191,600</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				19,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">195,000</span></td>
# 					<td class="num"><span class="tah p11">199,700</span></td>
# 					<td class="num"><span class="tah p11">188,100</span></td>
# 					<td class="num"><span class="tah p11">53,959,129</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.04</span></td>
# 					<td class="num"><span class="tah p11">172,200</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				22,900
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">184,200</span></td>
# 					<td class="num"><span class="tah p11">195,900</span></td>
# 					<td class="num"><span class="tah p11">171,900</span></td>
# 					<td class="num"><span class="tah p11">89,427,954</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table summary="페이지 네비게이션 리스트" class="Nnavi" align="center">
# 				<caption>페이지 네비게이션</caption>
# 				<tr>
#
#
#
#                 <td class="on">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >1</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=2"  >2</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=3"  >3</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=4"  >4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=5"  >5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=6"  >6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=7"  >7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=8"  >8</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=9"  >9</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=10"  >10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=11"  >
# 				다음<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=744"  >맨뒤
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/jindo.min.ns.1.5.3.euckr.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/ntm.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/nLog.js"></script>
# 	<script type="text/javascript">
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
# 	</script>
#
# </body>
#
# --------------------------------------------------
# --- 2페이지 HTML 정보 출력 ---
#
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <title>Npay 증권</title>
#
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/common.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/finance_header.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/layout.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/main.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock2.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock3.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/world.css">
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.03.03</span></td>
# 					<td class="num"><span class="tah p11">195,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				21,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">209,500</span></td>
# 					<td class="num"><span class="tah p11">212,500</span></td>
# 					<td class="num"><span class="tah p11">195,100</span></td>
# 					<td class="num"><span class="tah p11">54,879,010</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.27</span></td>
# 					<td class="num"><span class="tah p11">216,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				1,500
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">210,000</span></td>
# 					<td class="num"><span class="tah p11">223,000</span></td>
# 					<td class="num"><span class="tah p11">210,000</span></td>
# 					<td class="num"><span class="tah p11">51,774,768</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.26</span></td>
# 					<td class="num"><span class="tah p11">218,000</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				14,500
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">206,500</span></td>
# 					<td class="num"><span class="tah p11">219,000</span></td>
# 					<td class="num"><span class="tah p11">206,000</span></td>
# 					<td class="num"><span class="tah p11">30,095,763</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.25</span></td>
# 					<td class="num"><span class="tah p11">203,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				3,500
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">202,500</span></td>
# 					<td class="num"><span class="tah p11">206,000</span></td>
# 					<td class="num"><span class="tah p11">201,000</span></td>
# 					<td class="num"><span class="tah p11">26,987,996</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.24</span></td>
# 					<td class="num"><span class="tah p11">200,000</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				7,000
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">193,000</span></td>
# 					<td class="num"><span class="tah p11">200,000</span></td>
# 					<td class="num"><span class="tah p11">192,000</span></td>
# 					<td class="num"><span class="tah p11">28,060,617</span></td>
# 					</tr>
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="1" bgcolor="#e1e1e1"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.23</span></td>
# 					<td class="num"><span class="tah p11">193,000</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,900
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">194,400</span></td>
# 					<td class="num"><span class="tah p11">197,600</span></td>
# 					<td class="num"><span class="tah p11">190,500</span></td>
# 					<td class="num"><span class="tah p11">26,364,684</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.20</span></td>
# 					<td class="num"><span class="tah p11">190,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">190,000</span></td>
# 					<td class="num"><span class="tah p11">190,300</span></td>
# 					<td class="num"><span class="tah p11">188,600</span></td>
# 					<td class="num"><span class="tah p11">24,213,880</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.19</span></td>
# 					<td class="num"><span class="tah p11">190,000</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				8,800
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">188,000</span></td>
# 					<td class="num"><span class="tah p11">190,900</span></td>
# 					<td class="num"><span class="tah p11">187,100</span></td>
# 					<td class="num"><span class="tah p11">27,049,388</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.13</span></td>
# 					<td class="num"><span class="tah p11">181,200</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,600
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">179,500</span></td>
# 					<td class="num"><span class="tah p11">184,400</span></td>
# 					<td class="num"><span class="tah p11">178,900</span></td>
# 					<td class="num"><span class="tah p11">34,454,192</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.12</span></td>
# 					<td class="num"><span class="tah p11">178,600</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				10,800
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">171,200</span></td>
# 					<td class="num"><span class="tah p11">179,600</span></td>
# 					<td class="num"><span class="tah p11">170,100</span></td>
# 					<td class="num"><span class="tah p11">41,296,011</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table summary="페이지 네비게이션 리스트" class="Nnavi" align="center">
# 				<caption>페이지 네비게이션</caption>
# 				<tr>
#
# 				<td class="pgLL">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarLL.gif" width="7" height="5" alt="">맨앞
# 				</a>
# 				</td>
#
#
#                 <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >1</a>
# 				</td>
# <td class="on">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=2"  >2</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=3"  >3</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=4"  >4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=5"  >5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=6"  >6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=7"  >7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=8"  >8</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=9"  >9</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=10"  >10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=11"  >
# 				다음<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=744"  >맨뒤
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/jindo.min.ns.1.5.3.euckr.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/ntm.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/nLog.js"></script>
# 	<script type="text/javascript">
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
# 	</script>
#
# </body>
#
# --------------------------------------------------
# --- 3페이지 HTML 정보 출력 ---
#
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <title>Npay 증권</title>
#
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/common.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/finance_header.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/layout.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/main.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock2.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock3.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/world.css">
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.11</span></td>
# 					<td class="num"><span class="tah p11">167,800</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,000
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">164,000</span></td>
# 					<td class="num"><span class="tah p11">168,600</span></td>
# 					<td class="num"><span class="tah p11">162,000</span></td>
# 					<td class="num"><span class="tah p11">22,760,242</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.10</span></td>
# 					<td class="num"><span class="tah p11">165,800</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				600
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">167,400</span></td>
# 					<td class="num"><span class="tah p11">168,100</span></td>
# 					<td class="num"><span class="tah p11">165,500</span></td>
# 					<td class="num"><span class="tah p11">19,369,566</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.09</span></td>
# 					<td class="num"><span class="tah p11">166,400</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				7,800
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">168,600</span></td>
# 					<td class="num"><span class="tah p11">168,700</span></td>
# 					<td class="num"><span class="tah p11">165,000</span></td>
# 					<td class="num"><span class="tah p11">25,098,971</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.06</span></td>
# 					<td class="num"><span class="tah p11">158,600</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				700
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">154,100</span></td>
# 					<td class="num"><span class="tah p11">160,300</span></td>
# 					<td class="num"><span class="tah p11">151,600</span></td>
# 					<td class="num"><span class="tah p11">36,358,081</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.05</span></td>
# 					<td class="num"><span class="tah p11">159,300</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				9,800
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">162,000</span></td>
# 					<td class="num"><span class="tah p11">164,000</span></td>
# 					<td class="num"><span class="tah p11">158,500</span></td>
# 					<td class="num"><span class="tah p11">38,435,228</span></td>
# 					</tr>
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="1" bgcolor="#e1e1e1"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.04</span></td>
# 					<td class="num"><span class="tah p11">169,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				1,600
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">163,500</span></td>
# 					<td class="num"><span class="tah p11">169,400</span></td>
# 					<td class="num"><span class="tah p11">163,100</span></td>
# 					<td class="num"><span class="tah p11">29,943,042</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.03</span></td>
# 					<td class="num"><span class="tah p11">167,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				17,100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">157,900</span></td>
# 					<td class="num"><span class="tah p11">167,500</span></td>
# 					<td class="num"><span class="tah p11">157,200</span></td>
# 					<td class="num"><span class="tah p11">36,529,813</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.02.02</span></td>
# 					<td class="num"><span class="tah p11">150,400</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				10,100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">155,700</span></td>
# 					<td class="num"><span class="tah p11">159,600</span></td>
# 					<td class="num"><span class="tah p11">150,400</span></td>
# 					<td class="num"><span class="tah p11">39,748,369</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.30</span></td>
# 					<td class="num"><span class="tah p11">160,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">160,100</span></td>
# 					<td class="num"><span class="tah p11">166,500</span></td>
# 					<td class="num"><span class="tah p11">160,100</span></td>
# 					<td class="num"><span class="tah p11">40,557,267</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.29</span></td>
# 					<td class="num"><span class="tah p11">160,700</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				1,700
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">166,200</span></td>
# 					<td class="num"><span class="tah p11">166,600</span></td>
# 					<td class="num"><span class="tah p11">157,100</span></td>
# 					<td class="num"><span class="tah p11">36,087,223</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table summary="페이지 네비게이션 리스트" class="Nnavi" align="center">
# 				<caption>페이지 네비게이션</caption>
# 				<tr>
#
# 				<td class="pgLL">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarLL.gif" width="7" height="5" alt="">맨앞
# 				</a>
# 				</td>
#
#
#                 <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >1</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=2"  >2</a>
# 				</td>
# <td class="on">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=3"  >3</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=4"  >4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=5"  >5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=6"  >6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=7"  >7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=8"  >8</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=9"  >9</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=10"  >10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=11"  >
# 				다음<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=744"  >맨뒤
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/jindo.min.ns.1.5.3.euckr.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/ntm.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/nLog.js"></script>
# 	<script type="text/javascript">
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
# 	</script>
#
# </body>
#
# --------------------------------------------------
# --- 4페이지 HTML 정보 출력 ---
#
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <title>Npay 증권</title>
#
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/common.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/finance_header.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/layout.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/main.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock2.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock3.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/world.css">
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.28</span></td>
# 					<td class="num"><span class="tah p11">162,400</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,900
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">162,600</span></td>
# 					<td class="num"><span class="tah p11">163,300</span></td>
# 					<td class="num"><span class="tah p11">160,200</span></td>
# 					<td class="num"><span class="tah p11">29,456,431</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.27</span></td>
# 					<td class="num"><span class="tah p11">159,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				7,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">150,500</span></td>
# 					<td class="num"><span class="tah p11">159,500</span></td>
# 					<td class="num"><span class="tah p11">149,200</span></td>
# 					<td class="num"><span class="tah p11">29,423,670</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.26</span></td>
# 					<td class="num"><span class="tah p11">152,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pn"><span class="blind">보합</span></em><span class="tah p11">0</span>
# 			</td>
# 					<td class="num"><span class="tah p11">154,900</span></td>
# 					<td class="num"><span class="tah p11">156,400</span></td>
# 					<td class="num"><span class="tah p11">151,500</span></td>
# 					<td class="num"><span class="tah p11">20,561,689</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.23</span></td>
# 					<td class="num"><span class="tah p11">152,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">154,700</span></td>
# 					<td class="num"><span class="tah p11">156,000</span></td>
# 					<td class="num"><span class="tah p11">150,100</span></td>
# 					<td class="num"><span class="tah p11">25,407,497</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.22</span></td>
# 					<td class="num"><span class="tah p11">152,300</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,800
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">155,000</span></td>
# 					<td class="num"><span class="tah p11">157,000</span></td>
# 					<td class="num"><span class="tah p11">150,800</span></td>
# 					<td class="num"><span class="tah p11">32,073,624</span></td>
# 					</tr>
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="1" bgcolor="#e1e1e1"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.21</span></td>
# 					<td class="num"><span class="tah p11">149,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				4,300
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">141,900</span></td>
# 					<td class="num"><span class="tah p11">149,800</span></td>
# 					<td class="num"><span class="tah p11">141,800</span></td>
# 					<td class="num"><span class="tah p11">31,703,610</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.20</span></td>
# 					<td class="num"><span class="tah p11">145,200</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				4,100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">148,500</span></td>
# 					<td class="num"><span class="tah p11">149,300</span></td>
# 					<td class="num"><span class="tah p11">143,900</span></td>
# 					<td class="num"><span class="tah p11">24,059,218</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.19</span></td>
# 					<td class="num"><span class="tah p11">149,300</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">147,200</span></td>
# 					<td class="num"><span class="tah p11">150,600</span></td>
# 					<td class="num"><span class="tah p11">146,600</span></td>
# 					<td class="num"><span class="tah p11">22,762,497</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.16</span></td>
# 					<td class="num"><span class="tah p11">148,900</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				5,000
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">145,300</span></td>
# 					<td class="num"><span class="tah p11">149,500</span></td>
# 					<td class="num"><span class="tah p11">144,300</span></td>
# 					<td class="num"><span class="tah p11">30,000,219</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.15</span></td>
# 					<td class="num"><span class="tah p11">143,900</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				3,600
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">139,000</span></td>
# 					<td class="num"><span class="tah p11">144,000</span></td>
# 					<td class="num"><span class="tah p11">138,300</span></td>
# 					<td class="num"><span class="tah p11">24,701,126</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table summary="페이지 네비게이션 리스트" class="Nnavi" align="center">
# 				<caption>페이지 네비게이션</caption>
# 				<tr>
#
# 				<td class="pgLL">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarLL.gif" width="7" height="5" alt="">맨앞
# 				</a>
# 				</td>
#
#
#                 <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >1</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=2"  >2</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=3"  >3</a>
# 				</td>
# <td class="on">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=4"  >4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=5"  >5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=6"  >6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=7"  >7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=8"  >8</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=9"  >9</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=10"  >10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=11"  >
# 				다음<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=744"  >맨뒤
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/jindo.min.ns.1.5.3.euckr.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/ntm.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/nLog.js"></script>
# 	<script type="text/javascript">
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
# 	</script>
#
# </body>
#
# --------------------------------------------------
# --- 5페이지 HTML 정보 출력 ---
#
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <title>Npay 증권</title>
#
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/common.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/finance_header.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/layout.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/main.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock2.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock3.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/world.css">
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.14</span></td>
# 					<td class="num"><span class="tah p11">140,300</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,700
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">137,000</span></td>
# 					<td class="num"><span class="tah p11">140,300</span></td>
# 					<td class="num"><span class="tah p11">136,800</span></td>
# 					<td class="num"><span class="tah p11">18,444,394</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.13</span></td>
# 					<td class="num"><span class="tah p11">137,600</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				1,200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">139,800</span></td>
# 					<td class="num"><span class="tah p11">140,200</span></td>
# 					<td class="num"><span class="tah p11">136,900</span></td>
# 					<td class="num"><span class="tah p11">22,384,699</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.12</span></td>
# 					<td class="num"><span class="tah p11">138,800</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">141,000</span></td>
# 					<td class="num"><span class="tah p11">142,000</span></td>
# 					<td class="num"><span class="tah p11">136,900</span></td>
# 					<td class="num"><span class="tah p11">26,271,134</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.09</span></td>
# 					<td class="num"><span class="tah p11">139,000</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">136,000</span></td>
# 					<td class="num"><span class="tah p11">140,700</span></td>
# 					<td class="num"><span class="tah p11">135,200</span></td>
# 					<td class="num"><span class="tah p11">29,520,566</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2026.01.08</span></td>
# 					<td class="num"><span class="tah p11">138,800</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				2,200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">138,300</span></td>
# ...
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.11.06</span></td>
# 					<td class="num"><span class="tah p11">99,200</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				1,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">103,700</span></td>
# 					<td class="num"><span class="tah p11">103,800</span></td>
# 					<td class="num"><span class="tah p11">98,800</span></td>
# 					<td class="num"><span class="tah p11">28,655,689</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.11.05</span></td>
# 					<td class="num"><span class="tah p11">100,600</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				4,300
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">101,000</span></td>
# 					<td class="num"><span class="tah p11">102,000</span></td>
# 					<td class="num"><span class="tah p11">96,700</span></td>
# 					<td class="num"><span class="tah p11">44,843,020</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.11.04</span></td>
# 					<td class="num"><span class="tah p11">104,900</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				6,200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">111,800</span></td>
# 					<td class="num"><span class="tah p11">112,400</span></td>
# 					<td class="num"><span class="tah p11">104,900</span></td>
# 					<td class="num"><span class="tah p11">30,450,281</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.11.03</span></td>
# 					<td class="num"><span class="tah p11">111,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				3,600
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">106,900</span></td>
# 					<td class="num"><span class="tah p11">111,500</span></td>
# 					<td class="num"><span class="tah p11">106,500</span></td>
# 					<td class="num"><span class="tah p11">30,110,066</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table summary="페이지 네비게이션 리스트" class="Nnavi" align="center">
# 				<caption>페이지 네비게이션</caption>
# 				<tr>
#
# 				<td class="pgLL">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarLL.gif" width="7" height="5" alt="">맨앞
# 				</a>
# 				</td>
#
#
#                 <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >1</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=2"  >2</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=3"  >3</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=4"  >4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=5"  >5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=6"  >6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=7"  >7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=8"  >8</a>
# 				</td>
# <td class="on">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=9"  >9</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=10"  >10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=11"  >
# 				다음<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=744"  >맨뒤
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/jindo.min.ns.1.5.3.euckr.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/ntm.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/nLog.js"></script>
# 	<script type="text/javascript">
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
# 	</script>
#
# </body>
#
# --------------------------------------------------
# --- 10페이지 HTML 정보 출력 ---
#
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <title>Npay 증권</title>
#
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/common.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/finance_header.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/layout.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/main.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock2.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/newstock3.css">
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/css/world.css">
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.31</span></td>
# 					<td class="num"><span class="tah p11">107,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				3,400
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">105,000</span></td>
# 					<td class="num"><span class="tah p11">108,600</span></td>
# 					<td class="num"><span class="tah p11">103,300</span></td>
# 					<td class="num"><span class="tah p11">54,824,564</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.30</span></td>
# 					<td class="num"><span class="tah p11">104,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				3,600
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">102,400</span></td>
# 					<td class="num"><span class="tah p11">105,800</span></td>
# 					<td class="num"><span class="tah p11">102,000</span></td>
# 					<td class="num"><span class="tah p11">34,570,017</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.29</span></td>
# 					<td class="num"><span class="tah p11">100,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				1,000
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">100,200</span></td>
# 					<td class="num"><span class="tah p11">101,000</span></td>
# 					<td class="num"><span class="tah p11">99,100</span></td>
# 					<td class="num"><span class="tah p11">20,899,788</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.28</span></td>
# 					<td class="num"><span class="tah p11">99,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				2,500
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">100,900</span></td>
# 					<td class="num"><span class="tah p11">101,000</span></td>
# 					<td class="num"><span class="tah p11">99,100</span></td>
# 					<td class="num"><span class="tah p11">20,002,282</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.27</span></td>
# 					<td class="num"><span class="tah p11">102,000</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				3,200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">101,300</span></td>
# 					<td class="num"><span class="tah p11">102,000</span></td>
# 					<td class="num"><span class="tah p11">100,600</span></td>
# 					<td class="num"><span class="tah p11">22,169,970</span></td>
# 					</tr>
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="1" bgcolor="#e1e1e1"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.24</span></td>
# 					<td class="num"><span class="tah p11">98,800</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				2,300
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">97,900</span></td>
# 					<td class="num"><span class="tah p11">99,000</span></td>
# 					<td class="num"><span class="tah p11">97,700</span></td>
# 					<td class="num"><span class="tah p11">18,801,925</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.23</span></td>
# 					<td class="num"><span class="tah p11">96,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				2,100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">96,800</span></td>
# 					<td class="num"><span class="tah p11">98,500</span></td>
# 					<td class="num"><span class="tah p11">96,300</span></td>
# 					<td class="num"><span class="tah p11">18,488,581</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.22</span></td>
# 					<td class="num"><span class="tah p11">98,600</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				1,100
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">97,100</span></td>
# 					<td class="num"><span class="tah p11">98,600</span></td>
# 					<td class="num"><span class="tah p11">95,500</span></td>
# 					<td class="num"><span class="tah p11">15,937,611</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.21</span></td>
# 					<td class="num"><span class="tah p11">97,500</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pdn"><span class="blind">하락</span></em><span class="tah p11 nv01">
# 				600
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">98,500</span></td>
# 					<td class="num"><span class="tah p11">99,900</span></td>
# 					<td class="num"><span class="tah p11">97,300</span></td>
# 					<td class="num"><span class="tah p11">22,803,830</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">
# 					<td align="center"><span class="tah p10 gray03">2025.10.20</span></td>
# 					<td class="num"><span class="tah p11">98,100</span></td>
# 					<td class="num">
# 				<em class="bu_p bu_pup"><span class="blind">상승</span></em><span class="tah p11 red02">
# 				200
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">97,900</span></td>
# 					<td class="num"><span class="tah p11">98,300</span></td>
# 					<td class="num"><span class="tah p11">96,000</span></td>
# 					<td class="num"><span class="tah p11">17,589,756</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table summary="페이지 네비게이션 리스트" class="Nnavi" align="center">
# 				<caption>페이지 네비게이션</caption>
# 				<tr>
#
# 				<td class="pgLL">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarLL.gif" width="7" height="5" alt="">맨앞
# 				</a>
# 				</td>
#
#
#                 <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=1"  >1</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=2"  >2</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=3"  >3</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=4"  >4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=5"  >5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=6"  >6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=7"  >7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=8"  >8</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.naver?code=005930&amp;page=9"  >9</a>
# 				</td>
# <td class="on">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=10"  >10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=11"  >
# 				다음<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.naver?code=005930&amp;page=744"  >맨뒤
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/jindo.min.ns.1.5.3.euckr.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/ntm.js"></script>
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260304232456/js/nLog.js"></script>
# 	<script type="text/javascript">
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
# 	</script>
#
# </body>
#
# --------------------------------------------------
